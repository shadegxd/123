# %%
#Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestRegressor
# Load and inspect the data
games = pd.read_csv('GeneralEsportData.csv')
earning = pd.read_csv('HistoricalEsportData.csv')

print(games.head())
print(earning.head())
# Out:
#                     Game  ReleaseDate     Genre  TotalEarnings  \
# 0         Age of Empires         1997  Strategy      510716.46
# 1      Age of Empires II         1999  Strategy     3253232.59
# 2     Age of Empires III         2005  Strategy      115843.65
# 3      Age of Empires IV         2021  Strategy      994675.03
# 4  Age of Empires Online         2011  Strategy        9806.56
#
#    OfflineEarnings  PercentOffline  TotalPlayers  TotalTournaments
# 0        375857.63        0.735942           473               265
# 1       1139384.57        0.350232          1994              1613
# 2         41800.00        0.360831           166               163
# 3        409117.93        0.411308           542               327
# 4           775.00        0.079029            44                50
#          Date                          Game  Earnings  Players  Tournaments
# 0  1998-01-01  Command & Conquer: Red Alert   15000.0        8            1
# 1  1998-01-01                    QuakeWorld   15000.0        8            1
# 2  1998-05-01                      Quake II   15000.0        4            1
# 3  1998-05-01            Total Annihilation   15000.0        2            1
# 4  1998-05-01                    QuakeWorld     300.0        3            1

# %%
print(games.describe())
# Out:
#        ReleaseDate  TotalEarnings  OfflineEarnings  PercentOffline  \
# count   650.000000   6.500000e+02     6.500000e+02      583.000000
# mean   2012.576923   2.527759e+06     1.774991e+06        0.659145
# std       7.436703   1.758171e+07     1.377120e+07        0.412233
# min    1981.000000   0.000000e+00     0.000000e+00        0.000000
# 25%    2007.000000   1.000000e+03     0.000000e+00        0.219244
# 50%    2015.000000   3.636129e+04     1.500000e+04        0.906896
# 75%    2019.000000   2.563600e+05     1.715892e+05        1.000000
# max    2023.000000   3.371080e+08     2.982906e+08        1.000000
#
#        TotalPlayers  TotalTournaments
# count    650.000000        650.000000
# mean     226.541538         94.078462
# std      964.342887        479.807202
# min        0.000000          0.000000
# 25%        4.000000          1.000000
# 50%       22.000000          5.000000
# 75%       99.500000         27.750000
# max    16272.000000       7245.000000

# %%
games.isnull().sum()
# Out:
# Game                 0
# ReleaseDate          0
# Genre                0
# TotalEarnings        0
# OfflineEarnings      0
# PercentOffline      67
# TotalPlayers         0
# TotalTournaments     0
# dtype: int64

# %%
# Adding a year column to the DataFrame
earning["Year"] = pd.DatetimeIndex(earning["Date"]).year
print(earning.head())
# Out:
#          Date                          Game  Earnings  Players  Tournaments  \
# 0  1998-01-01  Command & Conquer: Red Alert   15000.0        8            1
# 1  1998-01-01                    QuakeWorld   15000.0        8            1
# 2  1998-05-01                      Quake II   15000.0        4            1
# 3  1998-05-01            Total Annihilation   15000.0        2            1
# 4  1998-05-01                    QuakeWorld     300.0        3            1
#
#    Year
# 0  1998
# 1  1998
# 2  1998
# 3  1998
# 4  1998

# %%
# Checking the different Genres
print("The number of genres: " + str(games['Genre'].nunique()))
print(games['Genre'].unique())
print("The number of games: " + str(games['Game'].nunique()))
print(games['Game'].unique())
# Changing the names so it won't be too long 
games = games.apply(lambda x: x.replace({'Multiplayer Online Battle Arena':'MOBA', 'Third-Person Shooter':'TPS', "Role-Playing": 'RPG', "First-Person Shooter": "FPS"}, regex=True))
# Out:
# The number of genres: 12
# ['Strategy' 'FPS' 'MOBA' 'RPG Game' 'Fighting Game' 'Racing' 'Sports'
#  'Collectible Card Game' 'Puzzle Game' 'Battle Royale' 'TPS'
#  'Music / Rhythm Game']
# The number of games: 650
# ['Age of Empires' 'Age of Empires II' 'Age of Empires III'
#  'Age of Empires IV' 'Age of Empires Online' 'Age of Mythology' 'Among Us'
#  'Auto Chess' 'Brawl Stars' 'Chess.com' 'chess24' 'chessarena.com'
#  'Clash of Clans' 'Clash Royale' 'Clash Royale x Chess'
#  'Command & Conquer 3' 'Command & Conquer: Red Alert'
#  'Company of Heroes 2' 'ComPet' 'Dead By Daylight'
#  'Dead by Daylight Mobile' 'Dota Underlords' 'Endgods'
#  'Farming Simulator 19' 'Farming Simulator 22' 'Grey Goo'
#  'Heroes of Might and Magic III' 'Identity V' 'Internet Chess Club'
#  'Iron Harvest' 'Legion TD 2' 'Lichess' 'Loco Dojo Unleashed'
#  'Men of War: Assault Squad 2' 'Multigaming' 'Playchess.com' 'Pokémon GO'
#  'Pokémon VGC' 'Prophecy' 'Rise of Nations: Rise of Legends'
#  'Sea of Thieves' 'Star Wars: Squadrons' 'StarCraft II'
#  'StarCraft: Brood War' 'StarCraft: Remastered' 'Summoners War: Sky Arena'
#  'Super Mario Party' 'Supreme Commander'
#  'Supreme Commander: Forged Alliance' 'Teamfight Tactics' 'Temtem'
#  'TEPPEN' 'The Binding of Isaac' 'Total Annihilation' 'UNO' 'WarCraft III'
#  'WarCraft III: Reforged' 'Warhammer 40,000: Dawn of War'
#  'Warhammer 40,000: Dawn of War II' 'Warparty' 'Windjammers'
#  'World in Conflict' 'World of Tanks' 'World of Tanks Blitz' 'After-H'
#  'Aim Gods' 'Aliens versus Predator 2' 'Alliance of Valiant Arms'
#  'Archangel Hellfire' 'Arctic Combat' 'Battalion 1944' 'Battlefield 1'
#  'Battlefield 2' 'Battlefield 2142' 'Battlefield 3' 'Battlefield 4'
#  'Battlefield Hardline' 'Battlefield V' 'Beat Aim'
#  'Big Buck Hunter Arcade' 'Black Squad' 'Blaston' 'Borderlands 3'
#  'Call of Duty' 'Call of Duty 2' 'Call of Duty 4: Modern Warfare'
#  'Call of Duty: Advanced Warfare' 'Call of Duty: Black Ops'
#  'Call of Duty: Black Ops 2' 'Call of Duty: Black Ops 4'
#  'Call of Duty: Black Ops Cold War' 'Call of Duty: Black Ops III'
#  'Call of Duty: Blackout' 'Call of Duty: Ghosts'
#  'Call of Duty: Infinite Warfare' 'Call of Duty: Mobile'
#  'Call of Duty: Modern Warfare' 'Call of Duty: Modern Warfare 2'
#  'Call of Duty: Modern Warfare 3' 'Call of Duty: Modern Warfare II'
#  'Call of Duty: Vanguard' 'Call of Duty: Warzone'
#  'Call of Duty: Warzone 2.0' 'Call of Duty: WWII' 'Chex Quest'
#  'Contractors' 'Counter-Strike' 'Counter-Strike 2' 'Counter-Strike Online'
#  'Counter-Strike: Condition Zero' 'Counter-Strike: Global Offensive'
#  'Counter-Strike: Source' 'Critical Ops' 'CrossFire' 'CrossFire HD'
#  'CrossFire Mobile' 'Crysis' 'Day of Defeat' 'Day of Defeat: Source'
#  'Descent 3' 'Diabotical' 'Doom (2016)' 'Doom 3' 'Doom II: Hell on Earth'
#  'DOOMBRINGER' 'Echo Combat' 'Enemy Territory: Quake Wars'
#  'Escape from Tarkov' 'EV.IO' 'Evolve' 'F.E.A.R.'
#  'Ghost Recon Advanced Warfighter' 'Gundam Versus' 'Guns of Boom' 'Halo 2'
#  'Halo 2 Anniversary' 'Halo 3' 'Halo 4' 'Halo 5: Guardians'
#  'Halo Infinite' 'Halo: Combat Evolved' 'Halo: Reach' 'Ironsight'
#  'Islands of Nyne' 'Lemnis Gate' 'MechWarrior Online' 'Metal Gear Online'
#  'Onward' 'Overwatch' 'Overwatch 2' 'Painkiller' 'Paladins' 'Pavlov'
#  'Pistol Whip' 'Point Blank' 'Quake 4' 'Quake Champions' 'Quake II'
#  'Quake III Arena' 'Quake Live' 'QuakeWorld' 'Rage'
#  'Rainbow Six Extraction' 'Rainbow Six Siege' 'Rainbow Six: Vegas'
#  'Rainbow Six: Vegas 2' 'Realm Royale' 'Reflex' 'Resistance 2'
#  'Return to Castle Wolfenstein' 'Rust' 'S.K.I.L.L. - Special Force 2'
#  'S.T.A.L.K.E.R.: Shadow of Chernobyl' 'Shadowrun' 'ShootMania Storm'
#  'Snapshot VR' 'Space Junkies' 'Special Force' 'Splatoon' 'Splatoon 2'
#  'Star Wars Jedi Knight II: Jedi Outcast' 'Sudden Attack'
#  'Team Fortress 2' 'Tower Tag' "Uncharted 4: A Thief's End"
#  'Unreal Tournament' 'Unreal Tournament (2016)' 'Unreal Tournament 2003'
#  'Unreal Tournament 2004' 'Unreal Tournament 3' 'Vail VR' 'VAIL VR'
#  'VALORANT' 'Warface' 'Warsow' 'Wolfenstein: Enemy Territory' 'X8'
#  'Xonotic' 'Zombieland VR: Headshot Fever' 'Zula' 'Arena of Valor'
#  'Battlerite' 'Blankos Block Party' 'Bloodline Champions' 'Crab Game'
#  'Creative Destruction' 'Defense of the Ancients' 'Dofus' 'Dota 2'
#  'Dream Three Kingdoms 2' 'Heavy Metal Machines' 'Heroes of Newerth'
#  'Heroes of the Storm' 'Hyper Scape' 'League of Legends'
#  'League of Legends: Wild Rift' 'Legend of Glory' 'Minecraft'
#  'MOBA Legends' 'Mobile Legends: Bang Bang' 'Onmyoji Arena'
#  'Pokemon Unite' 'Roblox' 'Shards of War' 'SMITE'
#  'Splitgate: Arena Warfare' 'Teeworlds' 'Vainglory' 'Blade & Soul'
#  'Cave Digger 2' 'Chivalry 2' 'Guild Wars 2' 'Naraka: Bladepoint'
#  'Old School Runescape' 'Red Stone' 'Stardew Valley' 'World of WarCraft'
#  'Acceleration of SUGURI 2' 'Akatsuki Blitzkampf'
#  'Aquapazza: Aquaplus Dream Match' 'Arcana Heart 3'
#  'Arcana Heart 3: Love Max Six Stars!!!!!' 'Arcana Heart 3: LOVE MAX!!!!!'
#  'ARMS' 'Asuka 120% LimitOver BURNING Fest.'
#  'Attack on Titan Tribute Game' 'BlazBlue: Calamity Trigger'
#  'BlazBlue: Central Fiction' 'BlazBlue: Chronophantasma'
#  'BlazBlue: Chronophantasma Extend' 'BlazBlue: Continuum Shift Extend'
#  'BlazBlue: Continuum Shift II' 'BlazBlue: Cross Tag Battle' 'Brawlhalla'
#  'Brawlout' 'Breakers Revenge' 'Capcom vs. SNK' 'Capcom vs. SNK 2'
#  'Chaos Code: New Sign of Catastrophe' 'Dead or Alive 4' 'Dead or Alive 5'
#  'Dead or Alive 5 Ultimate' 'Dead or Alive 5: Last Round'
#  'Dead or Alive 6' 'Dead or Alive Ultimate' 'Def Jam: Fight for NY'
#  'Dengeki Bunko: Fighting Climax'
#  'Dengeki Bunko: Fighting Climax Ignition' 'Digimon Rumble Arena'
#  'Divekick' 'DNF Duel' 'Dragon Ball FighterZ' 'Dragon Ball Z: Budokai 3'
#  'Duck Game' 'Eternal Fighter Zero' 'Fantasy Strike' 'Fight of Animals'
#  "Fighter's History Dynamite" 'Fighting EX Layer'
#  'Garou: Mark of the Wolves' 'Granblue Fantasy: Versus' 'Guilty Gear'
#  'Guilty Gear -STRIVE-' 'Guilty Gear Xrd -REVELATOR-'
#  'Guilty Gear Xrd -SIGN-' 'Guilty Gear Xrd REV 2' 'Guilty Gear XX'
#  'Guilty Gear XX #Reload' 'Guilty Gear XX Accent Core'
#  'Guilty Gear XX Accent Core Plus' 'Guilty Gear XX Accent Core Plus R'
#  'Guilty Gear XX Slash' 'Hokuto no Ken' 'Hyper Street Fighter II'
#  'HYPERFIGHT' 'Injustice 2' 'Injustice: Gods Among Us'
#  "JoJo's Bizarre Adventure: All Star Battle R"
#  "JoJo's Bizarre Adventure: Heritage for the Future"
#  'Kill la Kill the Game: IF' 'Killer Instinct (2013)'
#  'King of Fighters 2002 Unlimited Match' 'King of Fighters 98'
#  'King of Fighters XI' 'King of Fighters XIII' 'King of Fighters XIV'
#  'King of Fighters XV' 'Kirby Fighters 2' 'Koihime Enbu'
#  'Lethal League Blaze' 'Maiden & Spell' 'Marvel vs. Capcom 2'
#  'Marvel vs. Capcom 3' 'Marvel vs. Capcom: Infinite'
#  'Melty Blood: Actress Again' 'Melty Blood: Actress Again Current Code'
#  'Melty Blood: Type Lumina' 'Mighty Fight Federation'
#  'Million Arthur: Arcana Blood' 'Mordhau' 'Mortal Kombat 11'
#  'Mortal Kombat 9' 'Mortal Kombat vs. DC Universe' 'Mortal Kombat X'
#  'Mortal Kombat XL' 'MultiVersus' 'Mystery Game Tournament'
#  'Naruto Shippuden: Ultimate Ninja Storm 4'
#  'Naruto: Gekitou Ninja Taisen! 4' 'Ninja Legends'
#  'Nitroplus Blasterz: Heroines Infinite Duel' 'Persona 4 Arena'
#  'Persona 4 Arena Ultimax' 'Pocket Bravery' 'Pocket Rumble'
#  'Pokkén Tournament' 'Pokkén Tournament DX' 'Power Instinct: Matrimelee'
#  'Power Rangers: Battle for the Grid' 'Power Rangers: Legacy Wars'
#  'Project Justice' 'Project M' 'Project Plus' 'Punch Planet' 'Red Earth'
#  'Rising Thunder' 'Rivals of Aether' 'Roof Rage' 'Rushdown Revolt'
#  'Sailor Moon S' 'Samurai Shodown (2019)' 'Samurai Shodown III'
#  'Samurai Shodown V Special' 'Schwarzerblitz' 'Sekiro: Shadows Die Twice'
#  'Shovel Knight Showdown' 'Shrek SuperSlam' 'Skullgirls'
#  'Skullgirls 2nd Encore' 'Skullgirls Encore' 'Slap City'
#  'SLAYERS FOR HIRE' 'Smash Remix' 'SNK Heroines: Tag Team Frenzy'
#  'Soul Calibur II' 'Soul Calibur II HD Online' 'Soul Calibur IV'
#  'Soul Calibur V' 'Soul Calibur VI' 'Stick Fight the Game'
#  'Street Fighter 6' 'Street Fighter Alpha 2' 'Street Fighter Alpha 3'
#  'Street Fighter EX2 Plus' 'Street Fighter III: 3rd Strike'
#  'Street Fighter IV' 'Street Fighter V' 'Street Fighter V: Arcade Edition'
#  'Street Fighter V: Champion Edition' 'Street Fighter X Tekken'
#  'Super Smash Bros.' 'Super Smash Bros. Brawl'
#  'Super Smash Bros. for Wii U' 'Super Smash Bros. Melee'
#  'Super Smash Bros. Ultimate' 'Super Street Fighter II Turbo'
#  'Super Street Fighter II Turbo HD Remix' 'Super Street Fighter IV'
#  'Super Street Fighter IV Arcade Edition'
#  'Tatsunoko vs. Capcom: Ultimate All-Stars'
#  'Teenage Mutant Ninja Turtles: Tournament Fighters' 'Tekken 4' 'Tekken 5'
#  'Tekken 5: Dark Resurrection' 'Tekken 6' 'Tekken 7'
#  'Tekken Tag Tournament' 'Tekken Tag Tournament 2' 'The Last Blade 2'
#  'The Unspoken' "Them's Fightin' Herds" 'Toribash' 'Tough Love Arena'
#  'Touhou Hisoutensoku ~ Choudokyuu Ginyoru no Nazo o Oe'
#  'TowerFall: Ascension' 'Ultimate Marvel vs. Capcom 3'
#  'Ultimate Mortal Kombat 3' 'Ultra Fight Da! Kyanta 2'
#  'Ultra Street Fighter IV' 'Umineko: Golden Fantasia'
#  'Under Night In-Birth EXE: Late' 'Under Night In-Birth EXE: Late[st]'
#  'Under Night In-Birth Exe:Late[cl-r]' 'Vampire Savior'
#  'Virtua Fighter 4: Evolution' 'Virtua Fighter 5'
#  'Virtua Fighter 5 Final Showdown' 'Virtua Fighter 5: Ultimate Showdown'
#  'Windjammers 2' 'WWE 2K20' 'Asphalt 4' 'Asphalt 9: Legends'
#  'Assetto Corsa' 'Assetto Corsa Competizione' 'Dirt Rally 2.0'
#  'Epic Roller Coasters VR' 'F1 2018' 'F1 2019' 'F1 2020' 'F1 2021' 'F1 22'
#  'Forza Horizon 5' 'Forza Motorsport 2' 'Forza Motorsport 3'
#  'Forza Motorsport 4' 'Forza Motorsport 6' 'Forza Motorsport 7'
#  'Gran Turismo 3: A-Spec' 'Gran Turismo 4' 'Gran Turismo Sport'
#  'GRID (2019)' 'Hot Lap League' 'iRacing.com' 'Jak 3'
#  'Jak and Daxter: The Precursur Legacy' 'Jak II' 'KartRider'
#  'Live for Speed' 'Mad Skills Motocross 2' 'Marbles on Stream'
#  'Mario Kart 8 Deluxe' 'NASCAR Heat 4' 'Nascar Heat 5'
#  'NASCAR Thunder 2002' 'NASCAR Thunder 2003' 'Need for Speed Carbon'
#  'Need for Speed: Most Wanted' 'Need for Speed: ProStreet'
#  'Need for Speed: Shift' 'Need for Speed: Underground'
#  'Need for Speed: Underground 2' 'Project Cars' 'Project Cars 2'
#  'Project Gotham Racing 2' 'Project Gotham Racing 3'
#  'Project Gotham Racing 4' 'RaceRoom Racing Experience' 'Rennsport'
#  'rFactor' 'rFactor 2' 'Speedrunners' 'Sprint Vector' 'Trackmania (2020)'
#  'TrackMania 2: Canyon' 'TrackMania 2: Stadium' 'Trackmania 2: Valley'
#  'TrackMania Nations' 'TrackMania Nations Forever' 'Trackmania Turbo'
#  'Trackmania United' 'Trackmania United Forever' 'Trials Fusion'
#  'Turbo Racing League' 'Void Racer' 'WRC 10 FIA World Rally Championship'
#  'Carom 3D' 'Dream league Soccer' 'EA Sports FC Online' 'Echo Arena'
#  'eFootball' 'Eleven Table Tennis' 'FIFA 03' 'FIFA 04' 'FIFA 05' 'FIFA 06'
#  'FIFA 07' 'FIFA 08' 'FIFA 09' 'FIFA 10' 'FIFA 11' 'FIFA 12' 'FIFA 13'
#  'FIFA 14' 'FIFA 15' 'FIFA 16' 'FIFA 17' 'FIFA 18' 'FIFA 19' 'FIFA 20'
#  'FIFA 2000' 'FIFA 2001' 'FIFA 2002 World Cup' 'FIFA 21' 'FIFA 22'
#  'FIFA 23' 'FIFA Online 3' 'FIFA Online 4' 'GOLF Plus'
#  'Golf With Your Friends' 'Gran Turismo 7' 'Groove Gunner'
#  'Gym Masters VR' 'Just Hoops' 'Madden NFL 19' 'Madden NFL 20'
#  'Madden NFL 2004' 'Madden NFL 2006' 'Madden NFL 2007' 'Madden NFL 2008'
#  'Madden NFL 2009' 'Madden NFL 2013' 'Madden NFL 2016' 'Madden NFL 2017'
#  'Madden NFL 2018' 'Madden NFL 21' 'Madden NFL 22' 'Madden NFL 23'
#  'Madden NFL 24' 'Mario Tennis Aces' 'NBA 2K Online' 'NBA 2K Online 2'
#  'NBA 2K18' 'NBA 2K19' 'NBA 2K20' 'NBA 2K21' 'NBA 2K22' 'NBA 2K23'
#  "NHL '94" 'NHL 12' 'NHL 13' 'NHL 14' 'NHL 15' 'NHL 17' 'NHL 18' 'NHL 19'
#  'NHL 23' 'Nock' 'Pro Evolution Soccer 2008' 'Pro Evolution Soccer 2009'
#  'Pro Evolution Soccer 2013' 'Pro Evolution Soccer 2014'
#  'Pro Evolution Soccer 2015' 'Pro Evolution Soccer 2016'
#  'Pro Evolution Soccer 2017' 'Pro Evolution Soccer 2018'
#  'Pro Evolution Soccer 2019' 'Pro Evolution Soccer 3'
#  'Pro Evolution Soccer 4' 'Pro Evolution Soccer 5'
#  'Pro Evolution Soccer 6' 'Racket: NX' 'Ragnaröck' 'Rezzil Player'
#  'Rocket League' 'Rocket League Sideswipe' 'Roller Champions'
#  'Slapshot Rebound' 'Soccer Stars' 'SuperPlayer' 'Synth Riders'
#  'Walkabout Mini Golf' 'Zwift' 'Artifact Classic' 'Artifact Foundry'
#  'Faeria' 'Gwent' 'Hand of the Gods' 'Hearthstone'
#  'Hearthstone Battlegrounds' 'KARDS, The World War II Card Game'
#  'Legends of Runeterra' 'Magic: The Gathering Arena'
#  'Magic: The Gathering Online' 'Mythgard' 'Pokémon TCG' 'Shadowverse'
#  'Shardbound' 'The Elder Scrolls: Legends' 'Yu-Gi-Oh! Duel Links'
#  'Catherine' 'Catherine: Full Body' 'Cultris II' 'Jstris'
#  'Magical Drop III' 'Microsoft Excel' 'Pac-man' 'Panel Attack'
#  'Puyo Puyo Champions' 'Puyo Puyo Tetris' 'Puyo Puyo Tetris 2' 'Tetr.io'
#  'Tetris' 'Tetris Effect: Connected' 'Tetris Ultimate'
#  'Twinkle Star Sprites' 'Wise Star 2' 'Apex Legends' 'Apex Legends Mobile'
#  'Ark: Survival Of The Fittest' 'Fall Guys' 'Farlight 84' 'Fortnite'
#  'Free Fire' 'H1Z1' 'Penguin Paradise'
#  "PLAYERUNKNOWN'S BATTLEGROUNDS Mobile" 'PLAYERUNKNOWN’S BATTLEGROUNDS'
#  'Radical Heights' 'Ring of Elysium' 'Rocket Arena' 'Rules Of Survival'
#  'Spellbreak' 'Super People' 'Gears 5' 'Gears of War' 'Gears of War 2'
#  'Gears of War 3' 'Gears of War 4' 'Gears of War: Ultimate Edition'
#  'Knockout City' 'Mobile Suit Gundam: Extreme Vs Maxi Boost ON'
#  'Rogue Company' 'The Division 2' 'Audio Trip' 'Beat Saber'
#  'Guitar Hero 5' 'Guitar Hero III: Legends of Rock'
#  'Guitar Hero: World Tour' 'Just Dance 2014' 'osu!']

# %%
games_earning = earning.merge(games[['Game','Genre','ReleaseDate','TotalPlayers',]], how = 'left', on = 'Game')
print(games_earning.head())
# Out:
#          Date                          Game  Earnings  Players  Tournaments  \
# 0  1998-01-01  Command & Conquer: Red Alert   15000.0        8            1
# 1  1998-01-01                    QuakeWorld   15000.0        8            1
# 2  1998-05-01                      Quake II   15000.0        4            1
# 3  1998-05-01            Total Annihilation   15000.0        2            1
# 4  1998-05-01                    QuakeWorld     300.0        3            1
#
#    Year     Genre  ReleaseDate  TotalPlayers
# 0  1998  Strategy         1996             8
# 1  1998       FPS         1996            59
# 2  1998       FPS         1997            37
# 3  1998  Strategy         1997             2
# 4  1998       FPS         1996            59

# %%
games_earning = games_earning.loc[(games_earning["Earnings"]>0) & (games_earning["Players"]>0) ]
replace_names_dict = {
    "PLAYERUNKNOWN'S BATTLEGROUNDS Mobile": 'PUBG mobile',
    "PLAYERUNKNOWN’S BATTLEGROUNDS": 'PUBG',
    "Counter-Strike: Global Offensive": 'Counter-Strike'
}
games_earning['Game'] = games_earning['Game'].replace(replace_names_dict)
val = ['Overwatch', 'Rainbow Six Siege', 'StarCraft II', "PUBG", 'PUBG mobile', 'Arena of Valor', 'League of Legends', 'Fortnite', 'Counter-Strike', 'Dota 2']
games_earning = games_earning[games_earning['Game'].isin(val)]
games_earning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1161 entries, 52 to 9237
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1161 non-null   object
#  1   Game          1161 non-null   object
#  2   Earnings      1161 non-null   float64
#  3   Players       1161 non-null   int64
#  4   Tournaments   1161 non-null   int64
#  5   Year          1161 non-null   int32
#  6   Genre         1161 non-null   object
#  7   ReleaseDate   1161 non-null   int64
#  8   TotalPlayers  1161 non-null   int64
# dtypes: float64(1), int32(1), int64(4), object(3)
# memory usage: 86.2+ KB

# %%
games_earning_pivot = pd.DataFrame()
games_earning_pivot = pd.pivot_table(games_earning, values = ['Game','Genre', 'Players','Tournaments', 'Earnings','TotalPlayers'],\
                                     index = ['Game','Year','Players', 'Earnings','Tournaments','TotalPlayers'], aggfunc = {'Genre': 'first',})
games_earning_pivot.reset_index(inplace=True)
games_earning_pivot = games_earning_pivot.loc[(games_earning_pivot["Earnings"]>100000) & (games_earning_pivot["Players"]>10)]
print(games_earning_pivot.head(10))
games_earning_pivot.info()
# Out:
#               Game  Year  Players    Earnings  Tournaments  TotalPlayers Genre
# 1   Arena of Valor  2016       25   268305.50            1          1986  MOBA
# 2   Arena of Valor  2017       40   116610.00            1          1986  MOBA
# 4   Arena of Valor  2017       66   403146.24            1          1986  MOBA
# 5   Arena of Valor  2017      100   530785.05            6          1986  MOBA
# 6   Arena of Valor  2017      129   722847.80            3          1986  MOBA
# 7   Arena of Valor  2017      133   411824.23            3          1986  MOBA
# 11  Arena of Valor  2018       61   137891.56            2          1986  MOBA
# 12  Arena of Valor  2018      100   222562.09            3          1986  MOBA
# 13  Arena of Valor  2018      112   295192.40            3          1986  MOBA
# 14  Arena of Valor  2018      116  2329160.00            3          1986  MOBA
# <class 'pandas.core.frame.DataFrame'>
# Index: 846 entries, 1 to 1159
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          846 non-null    object
#  1   Year          846 non-null    int32
#  2   Players       846 non-null    int64
#  3   Earnings      846 non-null    float64
#  4   Tournaments   846 non-null    int64
#  5   TotalPlayers  846 non-null    int64
#  6   Genre         846 non-null    object
# dtypes: float64(1), int32(1), int64(3), object(2)
# memory usage: 49.6+ KB

# %%
features = ['Game','Year','Earnings', 'Genre','ReleaseDate','Tournaments','TotalPlayers']
X = games_earning_pivot.drop(['Players'], axis=1)
y = games_earning_pivot['Players']
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size=0.25, random_state=37)
X.head()
# Out:
#              Game  Year   Earnings  Tournaments  TotalPlayers Genre
# 1  Arena of Valor  2016  268305.50            1          1986  MOBA
# 2  Arena of Valor  2017  116610.00            1          1986  MOBA
# 4  Arena of Valor  2017  403146.24            1          1986  MOBA
# 5  Arena of Valor  2017  530785.05            6          1986  MOBA
# 6  Arena of Valor  2017  722847.80            3          1986  MOBA

# %%
non_numeric_cols = X_train.select_dtypes(include=['object']).columns
X_train = pd.get_dummies(X_train, columns=non_numeric_cols)

# %%
non_numeric_cols_test = X_test.select_dtypes(include=['object']).columns
X_test = pd.get_dummies(X_test, columns=non_numeric_cols)
X_test.describe()
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212 entries, 279 to 483
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    212 non-null    int32
#  1   Earnings                212 non-null    float64
#  2   Tournaments             212 non-null    int64
#  3   TotalPlayers            212 non-null    int64
#  4   Game_Arena of Valor     212 non-null    bool
#  5   Game_Counter-Strike     212 non-null    bool
#  6   Game_Dota 2             212 non-null    bool
#  7   Game_Fortnite           212 non-null    bool
#  8   Game_League of Legends  212 non-null    bool
#  9   Game_Overwatch          212 non-null    bool
#  10  Game_PUBG               212 non-null    bool
#  11  Game_PUBG mobile        212 non-null    bool
#  12  Game_Rainbow Six Siege  212 non-null    bool
#  13  Game_StarCraft II       212 non-null    bool
#  14  Genre_Battle Royale     212 non-null    bool
#  15  Genre_FPS               212 non-null    bool
#  16  Genre_MOBA              212 non-null    bool
#  17  Genre_Strategy          212 non-null    bool
# dtypes: bool(14), float64(1), int32(1), int64(2)
# memory usage: 10.4 KB

# %%
# Tune hyperparameters, find the best set of hyperparameters

# Random Forest
# Crossvalidating to find the best hyperparameters
param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

rf = RandomForestClassifier(random_state=37)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, n_jobs = -1)
grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
best_rf_model = grid_search.best_estimator_
# Out:
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
best_params
# Out:
# {'bootstrap': True,
#  'max_depth': 10,
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
# Create and train the Random Forest model
zero_division = 1
rf_model = RandomForestClassifier(bootstrap=True,max_depth=None,min_samples_leaf=4,min_samples_split=10,n_estimators=200)
rf_model.fit(X_train, y_train.values.ravel())

# Make predictions on the test data
rf_predictions = rf_model.predict(X_test)

# Evaluate the Random Forest model
rf_accuracy = accuracy_score(y_test, rf_predictions)
rf_classification_report = classification_report(y_test, rf_predictions)
print(f"Accuracy: {rf_accuracy}")
print("Classification Report:\n", rf_classification_report)
# Out:
# Accuracy: 0.018867924528301886
# Classification Report:
#                precision    recall  f1-score   support
#
#           25       0.00      0.00      0.00         1
#           34       0.00      0.00      0.00         1
#           40       0.00      0.00      0.00         1
#           41       0.00      0.00      0.00         1
#           43       0.00      0.00      0.00         1
#           49       0.00      0.00      0.00         1
#           55       0.00      0.00      0.00         0
#           56       0.00      0.00      0.00         0
#           60       1.00      0.50      0.67         2
#           62       0.00      0.00      0.00         1
#           65       0.00      0.00      0.00         0
#           66       0.00      0.00      0.00         1
#           69       0.00      0.00      0.00         0
#           72       0.00      0.00      0.00         1
#           76       0.00      0.00      0.00         2
#           77       0.17      1.00      0.29         1
#           82       0.00      0.00      0.00         0
#           84       0.00      0.00      0.00         1
#           85       0.00      0.00      0.00         1
#           87       0.00      0.00      0.00         2
#           88       0.00      0.00      0.00         1
#           90       0.00      0.00      0.00         1
#           92       0.00      0.00      0.00         1
#           95       0.00      0.00      0.00         1
#           96       0.00      0.00      0.00         0
#           98       0.00      0.00      0.00         2
#           99       0.00      0.00      0.00         0
#          100       0.00      0.00      0.00         0
#          101       0.00      0.00      0.00         0
#          102       0.00      0.00      0.00         2
#          103       0.00      0.00      0.00         1
#          105       1.00      1.00      1.00         1
#          107       0.00      0.00      0.00         2
#          109       0.00      0.00      0.00         0
#          110       0.00      0.00      0.00         1
#          111       0.00      0.00      0.00         1
#          112       0.00      0.00      0.00         1
#          114       0.00      0.00      0.00         0
#          116       0.00      0.00      0.00         1
#          119       1.00      0.50      0.67         2
#          120       0.00      0.00      0.00         0
#          121       0.00      0.00      0.00         1
#          122       0.00      0.00      0.00         0
#          124       0.00      0.00      0.00         1
#          125       0.00      0.00      0.00         2
#          126       0.00      0.00      0.00         2
#          127       0.00      0.00      0.00         2
#          128       0.00      0.00      0.00         1
#          129       0.00      0.00      0.00         1
#          130       0.00      0.00      0.00         0
#          131       0.00      0.00      0.00         1
#          132       0.00      0.00      0.00         1
#          133       0.00      0.00      0.00         1
#          135       0.00      0.00      0.00         2
#          136       0.00      0.00      0.00         1
#          137       0.00      0.00      0.00         0
#          138       0.00      0.00      0.00         1
#          141       0.00      0.00      0.00         1
#          142       0.00      0.00      0.00         1
#          144       0.00      0.00      0.00         0
#          145       0.00      0.00      0.00         1
#          147       0.00      0.00      0.00         2
#          148       0.00      0.00      0.00         1
#          149       0.00      0.00      0.00         1
#          150       0.00      0.00      0.00         2
#          151       0.00      0.00      0.00         1
#          152       0.00      0.00      0.00         0
#          153       0.00      0.00      0.00         2
#          154       0.00      0.00      0.00         1
#          155       0.00      0.00      0.00         1
#          156       0.00      0.00      0.00         0
#          157       0.00      0.00      0.00         3
#          160       0.00      0.00      0.00         1
#          163       0.00      0.00      0.00         2
#          167       0.00      0.00      0.00         1
#          168       0.00      0.00      0.00         0
#          169       0.00      0.00      0.00         1
#          170       0.00      0.00      0.00         1
#          173       0.00      0.00      0.00         0
#          174       0.00      0.00      0.00         1
#          175       0.00      0.00      0.00         1
#          177       0.00      0.00      0.00         1
#          178       0.00      0.00      0.00         1
#          179       0.00      0.00      0.00         1
#          180       0.00      0.00      0.00         2
#          182       0.00      0.00      0.00         2
#          183       0.00      0.00      0.00         1
#          185       0.00      0.00      0.00         1
#          187       0.00      0.00      0.00         1
#          188       0.00      0.00      0.00         0
#          189       0.00      0.00      0.00         1
#          190       0.00      0.00      0.00         0
#          191       0.00      0.00      0.00         1
#          192       0.00      0.00      0.00         1
#          193       0.00      0.00      0.00         1
#          194       0.00      0.00      0.00         2
#          195       0.00      0.00      0.00         0
#          196       0.00      0.00      0.00         2
#          197       0.00      0.00      0.00         0
#          198       0.00      0.00      0.00         1
#          201       0.00      0.00      0.00         1
#          202       0.00      0.00      0.00         0
#          203       0.00      0.00      0.00         0
#          205       0.00      0.00      0.00         1
#          209       0.00      0.00      0.00         0
#          210       0.00      0.00      0.00         0
#          211       0.00      0.00      0.00         1
#          212       0.00      0.00      0.00         1
#          213       0.00      0.00      0.00         1
#          214       0.00      0.00      0.00         1
#          215       0.00      0.00      0.00         0
#          216       0.00      0.00      0.00         0
#          217       0.00      0.00      0.00         1
#          218       0.00      0.00      0.00         1
#          219       0.00      0.00      0.00         0
#          221       0.00      0.00      0.00         1
#          222       0.00      0.00      0.00         2
#          224       0.00      0.00      0.00         2
#          226       0.00      0.00      0.00         1
#          227       0.00      0.00      0.00         1
#          228       0.00      0.00      0.00         2
#          229       0.00      0.00      0.00         0
#          231       0.00      0.00      0.00         1
#          232       0.00      0.00      0.00         1
#          234       0.00      0.00      0.00         1
#          236       0.00      0.00      0.00         1
#          237       0.00      0.00      0.00         1
#          238       0.00      0.00      0.00         1
#          239       0.00      0.00      0.00         2
#          241       0.00      0.00      0.00         1
#          245       0.00      0.00      0.00         1
#          250       0.00      0.00      0.00         1
#          252       0.00      0.00      0.00         1
#          258       0.00      0.00      0.00         1
#          260       0.00      0.00      0.00         0
#          262       0.00      0.00      0.00         1
#          266       0.00      0.00      0.00         0
#          274       0.00      0.00      0.00         1
#          278       0.00      0.00      0.00         1
#          280       0.00      0.00      0.00         0
#          282       0.00      0.00      0.00         0
#          283       0.00      0.00      0.00         0
#          284       0.00      0.00      0.00         0
#          285       0.00      0.00      0.00         1
#          286       0.00      0.00      0.00         2
#          288       0.00      0.00      0.00         0
#          290       0.00      0.00      0.00         1
#          291       0.00      0.00      0.00         2
#          294       0.00      0.00      0.00         1
#          296       0.00      0.00      0.00         1
#          301       0.00      0.00      0.00         1
#          306       0.00      0.00      0.00         0
#          309       0.00      0.00      0.00         1
#          310       0.00      0.00      0.00         0
#          311       0.00      0.00      0.00         1
#          317       0.00      0.00      0.00         0
#          320       0.00      0.00      0.00         1
#          322       0.00      0.00      0.00         1
#          325       0.00      0.00      0.00         1
#          326       0.00      0.00      0.00         0
#          327       0.00      0.00      0.00         1
#          333       0.00      0.00      0.00         1
#          335       0.00      0.00      0.00         1
#          336       0.00      0.00      0.00         1
#          340       0.00      0.00      0.00         0
#          342       0.00      0.00      0.00         1
#          347       0.00      0.00      0.00         0
#          350       0.00      0.00      0.00         1
#          352       0.00      0.00      0.00         2
#          353       0.00      0.00      0.00         0
#          355       0.00      0.00      0.00         1
#          361       0.00      0.00      0.00         1
#          362       0.00      0.00      0.00         1
#          363       0.00      0.00      0.00         0
#          371       0.00      0.00      0.00         1
#          376       0.00      0.00      0.00         1
#          381       0.00      0.00      0.00         1
#          384       0.00      0.00      0.00         0
#          389       0.00      0.00      0.00         1
#          395       0.00      0.00      0.00         1
#          403       0.00      0.00      0.00         0
#          408       0.00      0.00      0.00         1
#          410       0.00      0.00      0.00         1
#          411       0.00      0.00      0.00         1
#          414       0.00      0.00      0.00         1
#          419       0.00      0.00      0.00         1
#          422       0.00      0.00      0.00         1
#          426       0.00      0.00      0.00         0
#          427       0.00      0.00      0.00         1
#          432       0.00      0.00      0.00         1
#          434       0.00      0.00      0.00         1
#          436       0.00      0.00      0.00         2
#          438       0.00      0.00      0.00         0
#          447       0.00      0.00      0.00         1
#          465       0.00      0.00      0.00         1
#          471       0.00      0.00      0.00         1
#          473       0.00      0.00      0.00         0
#          475       0.00      0.00      0.00         1
#          476       0.00      0.00      0.00         1
#          483       0.00      0.00      0.00         2
#          484       0.00      0.00      0.00         0
#          485       0.00      0.00      0.00         0
#          486       0.00      0.00      0.00         0
#          490       0.00      0.00      0.00         1
#          491       0.00      0.00      0.00         0
#          513       0.00      0.00      0.00         1
#          518       0.00      0.00      0.00         1
#          520       0.00      0.00      0.00         2
#          527       0.00      0.00      0.00         0
#          534       0.00      0.00      0.00         0
#          535       0.00      0.00      0.00         1
#          536       0.00      0.00      0.00         0
#          549       0.00      0.00      0.00         0
#          559       0.00      0.00      0.00         0
#          561       0.00      0.00      0.00         1
#          564       0.00      0.00      0.00         0
#          580       0.00      0.00      0.00         1
#          591       0.00      0.00      0.00         2
#          602       0.00      0.00      0.00         0
#          629       0.00      0.00      0.00         0
#          642       0.00      0.00      0.00         1
#          658       0.00      0.00      0.00         1
#          683       0.00      0.00      0.00         1
#          726       0.00      0.00      0.00         1
#          731       0.00      0.00      0.00         1
#          750       0.00      0.00      0.00         1
#          753       0.00      0.00      0.00         1
#          756       0.00      0.00      0.00         1
#          761       0.00      0.00      0.00         1
#          779       0.00      0.00      0.00         1
#          783       0.00      0.00      0.00         0
#          821       0.00      0.00      0.00         1
#          822       0.00      0.00      0.00         0
#          839       0.00      0.00      0.00         0
#          840       0.00      0.00      0.00         0
#          849       0.00      0.00      0.00         1
#          851       0.00      0.00      0.00         0
#          855       0.00      0.00      0.00         1
#          866       0.00      0.00      0.00         0
#          869       0.00      0.00      0.00         0
#          871       0.00      0.00      0.00         0
#          883       0.00      0.00      0.00         1
#          943       0.00      0.00      0.00         0
#          946       0.00      0.00      0.00         0
#          965       0.00      0.00      0.00         1
#          967       0.00      0.00      0.00         0
#          985       0.00      0.00      0.00         1
#         1002       0.00      0.00      0.00         0
#         1004       0.00      0.00      0.00         0
#         1011       0.00      0.00      0.00         0
#         1020       0.00      0.00      0.00         0
#         1026       0.00      0.00      0.00         1
#         1043       0.00      0.00      0.00         0
#         1078       0.00      0.00      0.00         0
#         1096       0.00      0.00      0.00         0
#         1188       0.00      0.00      0.00         1
#         1233       0.00      0.00      0.00         1
#         1255       0.00      0.00      0.00         1
#         1337       0.00      0.00      0.00         1
#         1339       0.00      0.00      0.00         1
#         1355       0.00      0.00      0.00         0
#         1402       0.00      0.00      0.00         1
#         1545       0.00      0.00      0.00         1
#
#     accuracy                           0.02       212
#    macro avg       0.01      0.01      0.01       212
# weighted avg       0.02      0.02      0.02       212
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Nikita\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
best_rf_model.fit(X_train, y_train)
y_pred = best_rf_model.predict(X_test)
accuracy = accuracy_score( y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.009433962264150943

# %% [markdown]
# idk :(
# best i could get is 0.05
# i tried changing target variables, prediction methods, but it didnt work
# whatever i try, i assume it might be the dataset problem as the model can't determine true and false positives, therefore f1 score is 0 etc.
# I will visualize some graphs for the presentation tomorrow.
